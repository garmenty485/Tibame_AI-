# %%
# -*- coding: utf-8 -*-
import requests
from bs4 import BeautifulSoup
import re


new_list = []
url = 'https://money.udn.com/money/index'

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:57.0) Gecko/20100101 Firefox/57.0'}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
#print(response.text)
div_tag = soup.find_all('div', {'class':'story__list story__list--web'})

soup2 = BeautifulSoup(str(div_tag), 'html.parser')
a_tags = soup2.find_all('a')

for i in a_tags:
    print('title: {}, link: {}'.format(i.text, 'https://money.udn.com'+i['href']))
    new_list.append('https://money.udn.com'+i['href'])
# Out:
# title:
#           泰國軍艦沉船累計尋獲12罹難者 仍有17人失蹤        , link: https://money.udn.com/money/story/5599/6862944?from=edn_newest_index
# title:
#           林飛帆：議長選舉遵守黨決議 反省台南沉痾勿派系化        , link: https://money.udn.com/money/story/7307/6862943?from=edn_newest_index
# title:
#           與博客來和解 清潔阿姨不貪財僅收符合勞基法金額        , link: https://money.udn.com/money/story/5612/6862930?from=edn_newest_index
# title:
#           俄軍平安夜砲轟赫松釀7死 澤倫斯基痛斥「恐怖行為」        , link: https://money.udn.com/money/story/5599/6862929?from=edn_newest_index
# title:
#           美股現吉兆：巴菲特說的「金錢移轉」可能正在發生        , link: https://money.udn.comhttps://money.udn.com/money/story/5599/6861320?from=edn_hottest_index
# title:
#           美股現吉兆：巴菲特說的「金錢移轉」可能正在發生        , link: https://money.udn.comhttps://money.udn.com/money/story/5599/6861320?from=edn_hottest_index
# title:
#           浩鼎發明專利獲美核准        , link: https://money.udn.comhttps://money.udn.com/money/story/11074/6861111?from=edn_hottest_index
# title:
#           浩鼎發明專利獲美核准        , link: https://money.udn.comhttps://money.udn.com/money/story/11074/6861111?from=edn_hottest_index
# title:
#           五大品牌車廠 全面漲價        , link: https://money.udn.comhttps://money.udn.com/money/story/10871/6861331?from=edn_hottest_index
# title:
#           五大品牌車廠 全面漲價        , link: https://money.udn.comhttps://money.udn.com/money/story/10871/6861331?from=edn_hottest_index
# title:
#           台積3奈米 下周南科量產        , link: https://money.udn.comhttps://money.udn.com/money/story/5612/6861366?from=edn_hottest_index
# title:
#           台積3奈米 下周南科量產        , link: https://money.udn.comhttps://money.udn.com/money/story/5612/6861366?from=edn_hottest_index

# %%
div_tag
# Out:
# [<div class="story__list story__list--web">
#  <div class="story__item">
#  <span class="story__item--time">22:37 </span>
#  <a data-content_level="開放閱讀" data-story_list="list_最新" href="/money/story/5599/6862944?from=edn_newest_index" title="泰國軍艦沉船累計尋獲12罹難者 仍有17人失蹤">
#            泰國軍艦沉船累計尋獲12罹難者 仍有17人失蹤        </a>
#  </div>
#  </div>,
#  <div class="story__list story__list--web">
#  <div class="story__item">
#  <span class="story__item--time">22:36 </span>
#  <a data-content_level="開放閱讀" data-story_list="list_最新" href="/money/story/7307/6862943?from=edn_newest_index" title="林飛帆：議長選舉遵守黨決議 反省台南沉痾勿派系化">
#            林飛帆：議長選舉遵守黨決議 反省台南沉痾勿派系化        </a>
#  </div>
#  </div>,
#  <div class="story__list story__list--web">
#  <div class="story__item">
#  <span class="story__item--time">22:27 </span>
#  <a data-content_level="開放閱讀" data-story_list="list_最新" href="/money/story/5612/6862930?from=edn_newest_index" title="與博客來和解 清潔阿姨不貪財僅收符合勞基法金額">
#            與博客來和解 清潔阿姨不貪財僅收符合勞基法金額        </a>
#  </div>
#  </div>,
#  <div class="story__list story__list--web">
#  <div class="story__item">
#  <span class="story__item--time">22:27 </span>
#  <a data-content_level="開放閱讀" data-story_list="list_最新" href="/money/story/5599/6862929?from=edn_newest_index" title="俄軍平安夜砲轟赫松釀7死 澤倫斯基痛斥「恐怖行為」">
#            俄軍平安夜砲轟赫松釀7死 澤倫斯基痛斥「恐怖行為」        </a>
#  </div>
#  </div>,
#  <div class="story__list story__list--web">
#  <div class="story__list story__list--web">
#  <div class="story__item">
#  <span class="story__item--view">10847</span>
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/5599/6861320?from=edn_hottest_index" title="美股現吉兆：巴菲特說的「金錢移轉」可能正在發生">
#            美股現吉兆：巴菲特說的「金錢移轉」可能正在發生        </a>
#  </div>
#  </div>
#  </div>,
#  <div class="story__list story__list--web">
#  <div class="story__item">
#  <span class="story__item--view">10847</span>
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/5599/6861320?from=edn_hottest_index" title="美股現吉兆：巴菲特說的「金錢移轉」可能正在發生">
#            美股現吉兆：巴菲特說的「金錢移轉」可能正在發生        </a>
#  </div>
#  </div>,
#  <div class="story__list story__list--web">
#  <div class="story__list story__list--web">
#  <div class="story__item">
#  <span class="story__item--view">9626</span>
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/11074/6861111?from=edn_hottest_index" title="浩鼎發明專利獲美核准">
#            浩鼎發明專利獲美核准        </a>
#  </div>
#  </div>
#  </div>,
#  <div class="story__list story__list--web">
#  <div class="story__item">
#  <span class="story__item--view">9626</span>
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/11074/6861111?from=edn_hottest_index" title="浩鼎發明專利獲美核准">
#            浩鼎發明專利獲美核准        </a>
#  </div>
#  </div>,
#  <div class="story__list story__list--web">
#  <div class="story__list story__list--web">
#  <div class="story__item">
#  <span class="story__item--view">6084</span>
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/10871/6861331?from=edn_hottest_index" title="五大品牌車廠 全面漲價">
#            五大品牌車廠 全面漲價        </a>
#  </div>
#  </div>
#  </div>,
#  <div class="story__list story__list--web">
#  <div class="story__item">
#  <span class="story__item--view">6084</span>
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/10871/6861331?from=edn_hottest_index" title="五大品牌車廠 全面漲價">
#            五大品牌車廠 全面漲價        </a>
#  </div>
#  </div>,
#  <div class="story__list story__list--web">
#  <div class="story__list story__list--web">
#  <div class="story__item">
#  <span class="story__item--view">5611</span>
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/5612/6861366?from=edn_hottest_index" title="台積3奈米 下周南科量產">
#            台積3奈米 下周南科量產        </a>
#  </div>
#  </div>
#  </div>,
#  <div class="story__list story__list--web">
#  <div class="story__item">
#  <span class="story__item--view">5611</span>
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/5612/6861366?from=edn_hottest_index" title="台積3奈米 下周南科量產">
#            台積3奈米 下周南科量產        </a>
#  </div>
#  </div>]

# %%
a_tags
# Out:
# [<a data-content_level="開放閱讀" data-story_list="list_最新" href="/money/story/5599/6862944?from=edn_newest_index" title="泰國軍艦沉船累計尋獲12罹難者 仍有17人失蹤">
#            泰國軍艦沉船累計尋獲12罹難者 仍有17人失蹤        </a>,
#  <a data-content_level="開放閱讀" data-story_list="list_最新" href="/money/story/7307/6862943?from=edn_newest_index" title="林飛帆：議長選舉遵守黨決議 反省台南沉痾勿派系化">
#            林飛帆：議長選舉遵守黨決議 反省台南沉痾勿派系化        </a>,
#  <a data-content_level="開放閱讀" data-story_list="list_最新" href="/money/story/5612/6862930?from=edn_newest_index" title="與博客來和解 清潔阿姨不貪財僅收符合勞基法金額">
#            與博客來和解 清潔阿姨不貪財僅收符合勞基法金額        </a>,
#  <a data-content_level="開放閱讀" data-story_list="list_最新" href="/money/story/5599/6862929?from=edn_newest_index" title="俄軍平安夜砲轟赫松釀7死 澤倫斯基痛斥「恐怖行為」">
#            俄軍平安夜砲轟赫松釀7死 澤倫斯基痛斥「恐怖行為」        </a>,
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/5599/6861320?from=edn_hottest_index" title="美股現吉兆：巴菲特說的「金錢移轉」可能正在發生">
#            美股現吉兆：巴菲特說的「金錢移轉」可能正在發生        </a>,
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/5599/6861320?from=edn_hottest_index" title="美股現吉兆：巴菲特說的「金錢移轉」可能正在發生">
#            美股現吉兆：巴菲特說的「金錢移轉」可能正在發生        </a>,
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/11074/6861111?from=edn_hottest_index" title="浩鼎發明專利獲美核准">
#            浩鼎發明專利獲美核准        </a>,
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/11074/6861111?from=edn_hottest_index" title="浩鼎發明專利獲美核准">
#            浩鼎發明專利獲美核准        </a>,
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/10871/6861331?from=edn_hottest_index" title="五大品牌車廠 全面漲價">
#            五大品牌車廠 全面漲價        </a>,
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/10871/6861331?from=edn_hottest_index" title="五大品牌車廠 全面漲價">
#            五大品牌車廠 全面漲價        </a>,
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/5612/6861366?from=edn_hottest_index" title="台積3奈米 下周南科量產">
#            台積3奈米 下周南科量產        </a>,
#  <a data-content_level="開放閱讀" data-story_list="list_最熱" href="https://money.udn.com/money/story/5612/6861366?from=edn_hottest_index" title="台積3奈米 下周南科量產">
#            台積3奈米 下周南科量產        </a>]

# %%
from time import sleep
import os
from bs4 import BeautifulSoup
from urllib.request import urlretrieve

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

        
def save_news(url):
    
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:57.0) Gecko/20100101 Firefox/57.0'}

    response = requests.get(url, headers=headers)
    sleep(1)
    soup = BeautifulSoup(response.text, 'html.parser')
    new_title = soup.find_all('h1',{'id':'story_art_title'})

    save_path = './news/'+new_title[0].text.replace(':','')
    
    article_body = soup.find_all('section',{'id':'article_body'})
    print('new title: {}'.format(new_title[0].text))

    ## create folder
    createFolder(save_path)
    soup2 = BeautifulSoup(str(article_body[0]), 'html.parser')


    ## save article contens in folder
    with open(save_path+'/contents.txt', 'w', encoding='utf-8') as f:  
        p_tags = soup2.find_all('p')
        print('new content: ')
        for i in p_tags:
            print(i.text)
            f.write(i.text)

    ## save image in article        
    img_tags = soup2.find_all('img')
    print('save image: ')
    for i in img_tags:
        print(i['src'])
        urlretrieve(i['src'], save_path+'/'+i['title']+'.jpg')
    print('==========\n\n')
    

for new_url in new_list:
    print(new_url)
    try:
        save_news(new_url)
        sleep(3)
    except:
        print('跳過')
# Out:
# https://money.udn.com/money/story/5599/6862944?from=edn_newest_index
# new title: 泰國軍艦沉船累計尋獲12罹難者 仍有17人失蹤
# new content:
# 泰國海軍今天表示，旗下軍艦素可泰號6天前在暹羅灣（Gulf ofThailand）發生沉船事故後，今天在海上又找到6具遺體，使得累計死亡人數達12人，但仍有17名船員失蹤。
#
# 法新社報導，素可泰號（HTMS Sukhothai）18日晚間因電力系統受損，在泰國東南方外海約37公里處發生沉船意外，船上共有105名人員。事發後大規模搜救行動成功從海浪中救起76名船員。
#
# 泰國海軍透過聲明表示，「今天我們一共尋獲6具遺體」，且「初步證據」顯示這些遺體屬於素可泰號船員，但還會經過DNA檢測確認。
#
# 過去一週已尋獲另外6具遺體，並已證實是素可泰號船員。
#
# 泰國當局派遣直升機、無人偵察機與軍艦持續在海上進行地毯式搜索，盼能夠找到生還者。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/7307/6862943?from=edn_newest_index
# new title: 林飛帆：議長選舉遵守黨決議 反省台南沉痾勿派系化
# new content:
# 民進黨副秘書長林飛帆今天表示，將他反省台南市政亂象談話的用意「派系化」，無助解決問題；他呼籲，明天議長選舉遵守黨的決議，「議會不該再成為郭再欽和郭信良的禁臠」。
#
# 林飛帆日前反省台南市政亂象的發言，引發黨內派系解讀為「親賴系統」意志展現。林飛帆晚間被詢及此一問題時重申，發文用意很單純，台南的市政沉痾是集體鄉愿忍讓結果，他作為民進黨人，也有責任深自檢討，為何未能提早促成大家一起面對這些問題。
#
# 他指出，這些問題還有許多是現在進行式，當下與未來市政的整頓很重要，更是這幾天發言的唯一初衷。
#
# 林飛帆說，這兩天很多人想把問題再度導引到民進黨內的派系之爭，嘗試用派系目的來解釋他的用意；他再次強調，正因為過去無論是黨內還是黨外，習慣用派系角度詮釋對內的檢討反省，才讓台南的問題每下愈況，愈來愈糟。
#
# 林飛帆指出，不用把他的用意「派系化」，那對解決問題沒有幫助，並提醒，若是再用派系之爭來掩蓋問題本質，那問題只會更嚴重。
#
# 林飛帆說，明天就是議長選舉，他的態度立場很清楚，「議會不該再成為郭再欽和郭信良的禁臠」。黨也做成決議，「本黨各縣市議員除不得支持具黑金背景之人選外，也必須依照所屬黨團決議一致性投票，違反黨團決議者，就是最嚴厲黨紀處分」。
#
# 林飛帆表示，中評會主委賴瑞隆也表明，最嚴厲處分就是開除黨籍。他全力支持黨與中評會所做的決議跟態度。
#
# 對於郭再欽昨天的回應，林飛帆說，發文前就知道，郭再欽、郭信良等系統一定會反擊，甚至以派系之爭詮釋用意；但台南的沉痾若是不面對，不處理，影響會更大，民進黨人都有責任集體面對，他也有責任盡力阻止集團鄉愿導致的結果繼續發生。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5612/6862930?from=edn_newest_index
# new title: 與博客來和解 清潔阿姨不貪財僅收符合勞基法金額
# new content:
# 博客來網路書店涉及對清潔工「假承攬真僱傭」，引起外界批評聲浪。統一超商委任律師劉韋廷今天晚間表示，博客來已和該名清潔阿姨達成和解；清潔阿姨也表示，今天下午已和博客來達成協議，感謝大家。
#
# 針對涉及清潔工「假承攬真僱傭」勞資風波，博客來母公司統一超商今天上午火速對此回應，博客來總經理江呈欣立即調離現職，並即刻啟動內部調查，不過仍難澆熄外界批評聲浪。
#
# 統一超商委任律師劉韋廷今天晚間接受中央社記者電訪證實，博客來已和該名清潔阿姨達成和解，並簽署完和解書，因和解內容必須保密，無法透露具體和解金額。
#
# 劉韋廷提到，公司提出2個和解條件給該名清潔阿姨，除了符合勞基法的金額，也有提出優於勞基法的金額，希望展現公司誠意；不過，清潔阿姨只願意收符合勞基法的金額。
#
# 劉韋廷表示，最後和解金額是按清潔阿姨20餘年僱傭年資算出，例如勞退、勞保、資遣費等均有列入其中，並已由清潔阿姨確認過和解金額。
#
# 這名清潔阿姨則透過錄音表示，「今天下午和博客來達成協議的內容，為博客來公司彌補過去21年應給我的費用，多謝大家，也感謝博客來」。
#
# 律師陳又新23日在臉書發文揭露，一名在博客來打掃20幾年的清潔工，遭公司通知明年起不用再來，該名清潔工不僅過去從沒有勞健保、三節禮金，現在才知道自己連退休金也沒有。
#
# 陳又新貼文指出，該名清潔工表示自己不識字，結果博客來和清潔工簽署的是承攬契約，卻要打卡上下班等，恐涉及「假承攬真僱傭」，貼文一出，輿論譁然，要求博客來出面說明。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5599/6862929?from=edn_newest_index
# new title: 俄軍平安夜砲轟赫松釀7死 澤倫斯基痛斥「恐怖行為」
# new content:
# 12月24日是耶誕夜，也是俄國入侵烏克蘭滿10個月之日。俄軍這一天對烏克蘭南部城市赫松再度發動砲擊，至少造成七人死亡，58人受傷。烏克蘭總統澤倫斯基痛斥俄軍行為「恐怖」。
#
#
#
# 法新社報導，一名目擊者表示，砲擊一開始擊中一間百貨公司，接著有如下雨般密集落在一處市場。一名婦人站在丈夫的屍體旁痛哭，「醫護人員試著救他，但是他已經沒有心跳」。
#
#
#
# 澤倫斯基在Telegram發文痛斥俄軍的殺戳行為，「他們是為了侵略和好玩而殺人，這就是烏克蘭的真實生活。全世界都應該看著，我們正在對抗什麼樣的絕對邪惡」。俄軍24日砲擊烏克蘭部城市赫松，一名男子推著家當急忙逃離旁邊店家冒出的熊熊火光。（法新社）俄軍24日砲擊烏克蘭部城市赫松，街道一隅冒出濃煙。（歐新社）
# save image:
# https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2022/12/24/realtime/19748805.jpg&x=0&y=0&sw=0&sh=0&sl=W&fw=1050&exp=3600&exp=3600
# https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2022/12/24/realtime/19748806.jpg&x=0&y=0&sw=0&sh=0&sl=W&fw=1050&exp=3600&exp=3600
# ==========
#
#
# https://money.udn.comhttps://money.udn.com/money/story/5599/6861320?from=edn_hottest_index
# 跳過
# https://money.udn.comhttps://money.udn.com/money/story/5599/6861320?from=edn_hottest_index
# 跳過
# https://money.udn.comhttps://money.udn.com/money/story/11074/6861111?from=edn_hottest_index
# 跳過
# https://money.udn.comhttps://money.udn.com/money/story/11074/6861111?from=edn_hottest_index
# 跳過
# https://money.udn.comhttps://money.udn.com/money/story/10871/6861331?from=edn_hottest_index
# 跳過
# https://money.udn.comhttps://money.udn.com/money/story/10871/6861331?from=edn_hottest_index
# 跳過
# https://money.udn.comhttps://money.udn.com/money/story/5612/6861366?from=edn_hottest_index
# 跳過
# https://money.udn.comhttps://money.udn.com/money/story/5612/6861366?from=edn_hottest_index
# 跳過
